# %%
print('Product of 6,7,-9,2,-3,28, and -30')
a= 6*7*-9*2*-3*28*-30 
print(a)
# Out:
# Product of 6,7,-9,2,-3,28, and -30
# -1905120

# %%
print('●','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','●')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('‖','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','‖')
print('I','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','◦','','','','','','','','','I')
print('●','=','-','-','=','○','=','-','-','=','○','=','-','-','=','○','=','-','-','=','●')
# Out:
# ● = - - = ○ = - - = ○ = - - = ○ = - - = ●
# I         ◦         ◦         ◦         I
# ‖         ◦         ◦         ◦         ‖
# ‖         ◦         ◦         ◦         ‖
# I         ◦         ◦         ◦         I
# ○ = - - = ○ = - - = ○ = - - = ○ = - - = ○
# I         ◦         ◦         ◦         I
# ‖         ◦         ◦         ◦         ‖
# ‖         ◦         ◦         ◦         ‖
# I         ◦         ◦         ◦         I
# ○ = - - = ○ = - - = ○ = - - = ○ = - - = ○
# I         ◦         ◦         ◦         I
# ‖         ◦         ◦         ◦         ‖
# ‖         ◦         ◦         ◦         ‖
# I         ◦         ◦         ◦         I
# ○ = - - = ○ = - - = ○ = - - = ○ = - - = ○
# I         ◦         ◦         ◦         I
# ‖         ◦         ◦         ◦         ‖
# ‖         ◦         ◦         ◦         ‖
# I         ◦         ◦         ◦         I
# ● = - - = ○ = - - = ○ = - - = ○ = - - = ●
